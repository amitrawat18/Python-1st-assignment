# %% [markdown]
# ## **Question-1) Discuss String Slicing and provide examples.**
#
# Answer-1)  String slicing in Python refers to the ability to extract a substring from a string by specifying a range of indices. It allows you to efficiently access and manipulate portions of a string.
# The syntax for string slicing is:

# %%
string[start:end:step]

# %% [markdown]
# start: The index of the first character to include in the slice (inclusive). If omitted, it defaults to 0.
#
# end: The index of the character where the slice stops (exclusive). If omitted, it defaults to the end of the string.
#
# step: The step size or stride. It determines the interval between characters to include in the slice. If omitted, it defaults to 1.
#
# **Return Type**:-
#
# The result of a slicing operation is always a string (str type) that contains a subset of the characters from the original string.
#
# **String Slicing Examples**:-
#
# Let’s see how to use string slicing in Python with the examples below.
#
# Retrieve All Characters
# To retrieve the entire string, use slicing without specifying any parameters.

# %%
s="PW SKILLS"
# now we will write the syntax to get the entire string
s[::]
# Out:
# 'PW SKILLS'

# %% [markdown]
# **Explanation:**
#
#  Using [::] without specifying start, end, or step returns the complete string.
#
#
#  **Get All Characters Before or After a Specific Position:-**
#
# To get all the items from a specific position to the end of the string, we can specify the start index and leave the end blank.
# And to get all the items before a specific index, we can specify the end index while leaving start blank.

# %%
a="Data Science"
# now to get the characters of the world science only we will write the following syntax

a[5:13]
# here the starting index is 5 and end index is 13 because python gives the value of a character less than the specified index
# Out:
# 'Science'

# %% [markdown]
# **Extract Characters Between Two Positions:-**
#
# To extract characters between specific positions, provide both start and end indices.

# %%
name="Ganesh"
#now if we want just the characters "nes" we will write
name[2:5]
# Out:
# 'nes'

# %% [markdown]
# **Get Characters at Specific Intervals**:-
#
# To retrieve characters at regular intervals, use the step parameter.

# %%
m= "qaretimovu"
# in the above word if we want to retrieve the vowels we will use
m[1:10:2]

# here 1 defines the start index, 10 defines the last index and 2 defines the intervals
# Out:
# 'aeiou'

# %% [markdown]
# # **Using Negative Indexing in Slicing**:-
#
# Negative indexing is useful for accessing elements from the end of the String. The last element has an index of -1, the second last element -2, and so on.

# %%
k= "Environment"
k[-1]
# -1 represents the last index as negative indexing starts from th end
# Out:
# 't'

# %%
# we can use the same slicing methods for negative index
k="Environment"
k[-7:-1]
# Out:
# 'ronmen'

# %%
# when colon(:) is placed ahead of index it removes the value of given index and gives the rest of the value
k[:-1]
# Out:
# 'Environmen'

# %%
# when colon(:) is placed behind the index it gives the value of specified index
k[-1:]
# Out:
# 't'

# %% [markdown]
# **Reverse a String Using Slicing**:-
#
# To reverse a string, use a negative step value of -1, which moves from the end of the string to the beginning.

# %%
s = "Python"

# Reverse the string
print(s[::-1])
# Out:
# nohtyP

# %% [markdown]
# ##**Question-2)**    **Explain the key features of lists in Python.**
#
# **Answer-2)**:-  Lists in Python are one of the most versatile and commonly used data structures. Here are the key features of lists in Python:
#
# ## 1. Ordered Collection:-
# Lists maintain the order of elements. The order in which elements are inserted
#
# *   Lists maintain the order of elements. The order in which elements are inserted into a list is the order in which they are stored and accessed.
#
#
# *  Elements can be accessed using their index (starting from 0).
#
# ## 2. Mutable:-
# Lists are mutable, meaning that you can modify the elements after the list is created. You can add, remove, or change elements in place.
#
# ## 3. Heterogeneous Elements:-
# A list can contain elements of different data types. For example, a list can have integers, strings, and even other lists as elements:

# %%
items=["Pen", "Copy", 1 , 34, 25.56, True ]
print(items)
print(type(items))
# Out:
# ['Pen', 'Copy', 1, 34, 25.56, True]
# <class 'list'>

# %% [markdown]
# ## 4. Dynamic Size:-
# Lists in Python are dynamically sized, meaning they can grow or shrink as needed. There's no need to specify a fixed size when creating a list.
#
#
#
# ## 5. Access by Index:-
# Elements in a list can be accessed using their index. Python supports negative indexing, allowing you to access elements from the end of the list:

# %%
my_list=["Copy", "Pen", "Scale"]
my_list[0]
print(my_list[0])
# here indexing works the same way like in strings
# for index 1
my_list[1]
print(my_list[1])
# for index 2
print(my_list[2])
# Out:
# Copy
# Pen
# Scale

# %% [markdown]
# ## 6. Slicing:-
# You can extract a part (or "slice") of a list using slicing syntax
#
# ## 7. Supports Various Operations:-
# **Appending:** You can add elements to the end of a list using the .append() method.
#
# **Inserting:** Use .insert() to add an element at a specific index.
#
# **Removing:** Use .remove() to remove a specific element, or pop() to remove an element by index.
#
# **Concatenation and Repetition:** Lists can be concatenated using the + operator and repeated using the * operator.
#
#
#
# ##8. Supports Iteration:-
# You can easily iterate over the elements in a list using loops such as for

# %%
for item in my_list:
    print(item)
# Out:
# Copy
# Pen
# Scale

# %% [markdown]
# ## 9. Contains Various Built-in Methods:-
# Python lists come with a variety of built-in methods like:
#
# *     len() to get the number of elements.
#
# *     sort() and reverse() to modify the order of elements.
#
# *     extend() to extend a list by appending elements from another iterable.
#
# *     index() to find the index of a value
#
#
# *     count() to count how many times an element appears.
#
#
# ## 10. Can Contain Other Lists:-
# Lists can be nested. A list can contain other lists as elements (creating multidimensional or nested lists):

# %%
list1=[1, "a", "Aman"]
list2=[2, "b", "Ajay"]
list3=[3, "c", "Rohit"]
mylist=[[list1], [list2], [list3]]
print(mylist)
# Out:
# [[[1, 'a', 'Aman']], [[2, 'b', 'Ajay']], [[3, 'c', 'Rohit']]]

# %% [markdown]
# ## **Question-3)** **Describe how to access, modify, and delete elements in a list with examples**.
#
#  **Answer-3)**  In Python, lists are mutable, which means you can access, modify, and delete elements easily. Here’s a breakdown of how to perform these operations with examples:
#  ## 1. Accessing Elements in a List:-
# You can access elements in a list using indices. List indices start at 0, and you can also use negative indices to access elements from the end of the list.
#
# Access by Index
#
# * Positive indices count from the beginning (starting at 0).
#
# * Negative indices count from the end (starting at -1).

# %%
a=[25, 3.14, 5+2j, "Name", True]
# now using positive index we will access the elements
# to access the elements index wise
a[0]
print(a[0])
a[1]
print(a[1])
a[2]
print(a[2])
a[3]
print(a[3])
a[4]
print(a[4])
# Out:
# 25
# 3.14
# (5+2j)
# Name
# True

# %%
# now we will use negative indexing
a[-1]
print(a[-1])
a[-2]
print(a[-2])
a[-3]
print(a[-3])
a[-4]
print(a[-4])
a[-5]
print(a[-5])
# Out:
# True
# Name
# (5+2j)
# 3.14
# 25

# %% [markdown]
# ## 2. Modifying Elements in a List:-
# Since lists are mutable, you can modify existing elements by assigning a new value to a specific index.
#
# Lets take the example of a list of numbers

# %%
num=[10, 20, 30, 40, 50,]
# to change value of a paricular index
num[3]=35
print(num)
# Out:
# [10, 20, 30, 35, 50]

# %%
# to add extra item in a list we use .append

# adding a extra number at a particular index
# we use .insert keyword


num.insert(3, 99)
print(num)
# Out:
# [10, 20, 30, 99, 50]

# %% [markdown]
# ## Modifying a Range of Elements with Slicing:-
#
# You can also modify multiple elements at once using slicing and assignment.

# %%
num=[10, 20, 30 ,99, 50]
num[0:2]
# Out:
# [10, 20]

# %% [markdown]
# .append() is also used to add a item at the end of the list

# %% [markdown]
# ## 3. Deleting Elements:-
#
# You can remove elements using indexing, or using methods like del,  remove(), or pop().
#
# * Delete a single element by index using del:

# %%
new=[20, "Pen", 3.14, True, 8+4j]
del new[1]
print(new)
# Out:
# [20, 3.14, True, (8+4j)]

# %% [markdown]
# * Remove an element by value using remove():

# %%
new.remove(True)
print(new)
# Out:
# [20, 3.14, (8+4j)]

# %% [markdown]
# * Pop an element by index using pop(), which also returns the removed element:

# %%
new.pop(1)
print(new)
# Out:
# [20, (8+4j)]

# %% [markdown]
# ## **Question-4) Compare and contrast tuples and lists with examples.**
#
#  **Answer-4)**  Tuples and lists are both sequence data types in Python that can store multiple items, but they differ in several important ways. Here's a comparison of the two:
#  ## 1. Mutability:-
#
# * **List:** Lists are mutable, meaning their elements can be changed after creation. You can modify, add, or remove elements.
#
# * **Tuple:** Tuples are immutable, meaning once a tuple is created, its elements cannot be modified, added, or removed. This is because tuple store data
# which is not to be changed or has fix value
#
# Both List and Tuple are a ordered collection and heterogeneous but still list immutable and tuples are immutable

# %%
a=[12, "abc", True, 45, "Amit"]
a[3]=50
print(a)
print(type(a))

# we can see a is a list and value of 3rd index is changed
# Out:
# [12, 'abc', True, 50, 'Amit']
# <class 'list'>

# %%
b=(34, "xyz", 3.14, False)
print(type(b))
# with tuple there is no function of changing the value
# Out:
# <class 'tuple'>

# %% [markdown]
# ## 2. Syntax:-
# * **List:** Lists are created using square brackets [].
# * **Tuple:** Tuples are created using parentheses ().
#
#
# ## 3. Performance:-
# * **List:**  Lists tend to have slightly more overhead due to their mutability. Operations like adding or removing elements can be more resource-intensive.
#
# * **Tuple:** Tuples, being immutable, are more memory-efficient and can be faster than lists when used for fixed collections of items.

# %% [markdown]
# ## 4. Methods and Operations:-
# * **List:** Lists have a larger number of built-in methods because they are mutable. You can use methods like append(), remove(), extend(), pop(), insert(), etc.
#
# * **Tuple:** Tuples have fewer built-in methods since they are immutable. They only support methods like count() and max and min.

# %%
# functions of a LIST
a=[12, "abc", True, 45, "Amit"]
a.append("Hello")
# it will add a element at the last of the list
a.remove(45)
# a.remove() will remove the value which is entered
a.pop(0)
# this will remove the value of the index provided
a.insert(2, False)
print(a)
# Out:
# ['abc', True, False, 'Amit', 'Hello']

# %%
# functions of a tuple
t=(12, 16, 13, 14, 12 , 12, 16, 12, 12)
t.count(12)
print(t.count(12))
# this function allows us to count the number of times a value is repeated
print(max(t))
# this gives the maximum value of the tuple
print(min(t))
# this gives the min value of the tuple
# Out:
# 5
# 16
# 12

# %% [markdown]
# ## 5. Packing and Unpacking:-
#
# Both lists and tuples support packing and unpacking, where multiple values are grouped together in a collection (packing) and then extracted (unpacking).
#
#
# ## 6. Immutability and Hashing:-
# Because tuples are immutable, they are hashable and can be used as dictionary keys, whereas lists cannot be used as dictionary keys because they are mutable.

# %%
my_dict={(1,3,5): "Data Science"}
print(my_dict)
# Out:
# {(1, 3, 5): 'Data Science'}

# %% [markdown]
# ## 7. Use Cases:-
#
# * **List:** Lists are ideal when the data is likely to change, such as appending, removing, or modifying elements.
#  Lists are also used when you need to perform a lot of operations like sorting, appending, or extending.
#
# **Example use cases:**
#
# * Storing items that change over time (e.g., shopping cart items).
#
# * Managing a collection of objects that may need to be modified.
#
#
# * **Tuple:** Tuples are ideal when the data should remain constant, such as representing fixed collections or groups of items that shouldn't be changed (e.g., coordinates, days of the week). They are often used for heterogeneous data or as keys in dictionaries.
#
# **Example use cases:**
#
# * Storing a collection of related but fixed items (e.g., coordinates).
#
# * Returning multiple values from a function (e.g., (x, y)).
#
# * Using tuples as dictionary keys because they are hashable (lists are not).

# %% [markdown]
# ##**Question-5)** **Describe the key features of sets and provide examples of their use.**
#
# **Answer-5)**  In Python, a set is an unordered collection of unique elements. Sets are a fundamental data structure in Python, and they come with several key features that make them useful for various tasks.
#
# Here are the key features of sets, along with examples to demonstrate their use:
#
# ## 1 Unordered Collection:-
#
# * Sets do not maintain any order of elements. When you print a set, the order in which elements are displayed may not be the same as the order in which they were added.

# %%
s={"Sanjay", "Ankit", "Rohit", 1, 34, True}
print(s)
#we can see that elements are arranged in unordered way
# Out:
# {'Rohit', 1, 34, 'Sanjay', 'Ankit'}

# %% [markdown]
# ##2. Unique Elements:-
# A set automatically removes duplicate elements. If you try to add a duplicate element to a set, it will not be added.

# %%
sets={1,1,1,2,2,2,23,3, "Amit", "Ankit", "Amit"}
sets
# Out:
# {1, 2, 23, 3, 'Amit', 'Ankit'}

# %% [markdown]
# ## 3. Mutable:-
# * Sets are mutable, meaning you can add or remove elements after the set is created

# %%
set1={23, 45, "Dev", True, False}
# to remove a element w use.remove()
set1.remove(45)
# to add a element we use .add(90)
set1.add(90)
print(set1)
# Out:
# {False, True, 23, 'Dev', 90}

# %% [markdown]
# ## 4. No Indexing, Slicing, or Looping with Indexes:-
#
# * Sets do not support indexing, slicing, or accessing elements by position, because they are unordered
#
#  Indexing is not allowed
#
# print(set1[0])  # This would raise a TypeError: 'set' object is not subscriptable

# %% [markdown]
# ## 5. Set Operations:-
#
# Sets support mathematical set operations such as:
#
# * Union (| or union())
#
# * Intersection (& or intersection())
#
# * Difference (- or difference())
#
# * Symmetric Difference (^ or symmetric_difference())

# %%
# Create two sets
set_a = {1, 2, 3, 4}
set_b = {3, 4, 5, 6}

# Union (all unique elements from both sets)
union_set = set_a | set_b
print(union_set)  # Output: {1, 2, 3, 4, 5, 6}

# Intersection (elements common to both sets)
intersection_set = set_a & set_b
print(intersection_set)  # Output: {3, 4}

# Difference (elements in set_a but not in set_b)
difference_set = set_a - set_b
print(difference_set)  # Output: {1, 2}

# Symmetric Difference (elements in either set, but not both)
sym_diff_set = set_a ^ set_b
print(sym_diff_set)  # Output: {1, 2, 5, 6}
# Out:
# {1, 2, 3, 4, 5, 6}
# {3, 4}
# {1, 2}
# {1, 2, 5, 6}

# %% [markdown]
# ## 6. Set Comprehensions:-
#
# Just like lists and dictionaries, sets support set comprehensions, which allow you to construct sets in a compact way.

# %%
# Creating a set of squares using a set comprehension
r={2, 3, 4 ,5 ,6}
for square in r:
  print(square**2)
# Out:
# 4
# 9
# 16
# 25
# 36

# %% [markdown]
# ## 7. Membership Testing:-
#
# Sets are optimized for membership testing, meaning checking if an element is present in a set or not.

# %%
my_set = {1, 2, 3, 4}
print(5 in my_set)
print(2 in my_set)
# Out:
# False
# True

# %% [markdown]
# ## 8. Set Methods:-
# Sets have a variety of built-in methods to perform operations like adding, removing, and clearing elements.

# %%
my_set = {1, 2, 3}

# Add an element
my_set.add(4)
print(my_set)  # Output: {1, 2, 3, 4}

# Remove an element (raises KeyError if the element is not found)
my_set.remove(2)
print(my_set)  # Output: {1, 3, 4}

# Remove an element (does not raise an error if element is not found)
my_set.discard(5)  # No error even though 5 is not in the set
print(my_set)  # Output: {1, 3, 4}

# Pop an element (removes and returns an arbitrary element)
removed_element = my_set.pop()
print(removed_element)  # Output: 1 (or some other element, as sets are unordered)
print(my_set)  # Output: {3, 4}

# Clear the set (remove all elements)
my_set.clear()
print(my_set)  # Output: set()  (empty set)
# Out:
# {1, 2, 3, 4}
# {1, 3, 4}
# {1, 3, 4}
# 1
# {3, 4}
# set()

# %% [markdown]
# ## **Question-6) Discuss the use cases of tuples and sets in Python programming.**
#
#  **Answer-6)**  **Tuple:** Tuple is a collection of Python objects much like a list.
#
#  The sequence of values stored in a tuple can be of any type, and they are indexed by integers. The main characteristics of tuples are –
#
# * Tuple is an immutable sequence in python.
#
# * It cannot be changed or replaced since it is immutable.
#
# * It is defined under parenthesis().
#
# * Tuples can store any type of element.
#
# ## Use Cases of Tuples:-
#
# A tuple is an immutable ordered collection of elements, which makes it suitable for situations where you need to store a fixed collection of values that should not change. Tuples are also hashable, making them useful as dictionary keys.
#
# Here are some common use cases for tuples:
#
# *  **Storing Fixed Data:-**
# Tuples are ideal for representing fixed collections of related data, where the elements should not change. For example, tuples can be used to store picode, Date of Birth, Blood Group.

# %%
my_tuple=(246149, 144001)
print(my_tuple)
# Out:
# (246149, 144001)

# %% [markdown]
# * **Returning Multiple Values from Functions:-**
# Tuples are often used to return multiple values from a function. Since tuples can hold a fixed number of items, you can easily bundle together related data and return it as a single entity.

# %%
nums=(1, 34, 55, 67, 23, 56, 99)
print(max(nums))
print(min(nums))
print(len(nums))
# Out:
# 99
# 1
# 7

# %% [markdown]
# * **Tuple as Dictionary Keys:-**
# Since tuples are immutable (and hashable), they can be used as keys in dictionaries. Lists, on the other hand, cannot be used as dictionary keys because they are mutable.

# %%
my_loc={(97, 36): "Kotdwar", (63, 40): "Chhatarpur"}
print(my_loc)
# Out:
# {(97, 36): 'Kotdwar', (63, 40): 'Chhatarpur'}

# %% [markdown]
# * **Tuple Packing and Unpacking:-**
# Tuples are frequently used for packing and unpacking data. Python allows you to pack multiple values into a tuple and unpack them easily when needed.

# %%
data=("Amit", "23", "Data Analyst")
name, age, designation= data
print(name)
print(age)
print(designation)
# Out:
# Amit
# 23
# Data Analyst

# %% [markdown]
# ## Use Cases of Sets:-
#
# A set is an unordered collection of unique elements. Sets are highly efficient for tasks that involve membership testing, uniqueness, and performing mathematical set operations. Sets are mutable, meaning you can add and remove elements, but they do not allow duplicate elements.
#
# Here are some common use cases for sets:
#
# * **Eliminating Duplicate Elements:-**
# Sets are perfect for removing duplicates from a collection. When you need to ensure that an element only appears once, you can convert a list or other iterable into a set.

# %%
numbers = {1, 2, 3, 4, 4, 5, 5, 6}
print(numbers)
print(type(numbers))
# Out:
# {1, 2, 3, 4, 5, 6}
# <class 'set'>

# %% [markdown]
# * **Membership Testing:-**
# Since sets are implemented using hash tables, checking whether an item is in a set is very fast. This makes sets highly suitable for tasks that involve frequent membership testing.

# %%
members={"Ankit", "Aman", "Rohit", "Sagar"}
name=input("Please Enter your Name ")
if name in members:
  print("Access Granted")
else:
    print("Access Denied")
# Out:
# Please Enter your Name Sagar
# Access Granted

# %% [markdown]
# * **Set as a Dictionary Key (frozenset):-**
# Although regular sets are mutable and cannot be used as dictionary keys, frozensets are immutable and hashable. This makes them useful when you need to use a set-like structure as a dictionary key.

# %%
frozen_set = frozenset([1, 2, 3])
my_dict = {frozen_set: "value"}
print(my_dict)
# Out:
# {frozenset({1, 2, 3}): 'value'}

# %% [markdown]
# ##**Question-7) Describe how to add, modify, and delete items in a dictionary with examples.**
#
# **Answer:-** In Python, a dictionary is a mutable, unordered collection of key-value pairs, where each key is unique. Dictionaries allow you to store and retrieve data efficiently, and they support various operations to add, modify, and delete items.
# * **Adding items to a dictionary:-**

# %%
my_dict={"Name": "Amit", "Age": 23, "Id Number": 456789}
my_dict
# Out:
# {'Name': 'Amit', 'Age': 23, 'Id Number': 456789}

# %%
my_dict["Phone Number"]=123456
my_dict

# this is the syntax of adding a additional key, value pair in the dictionary
# Out:
# {'Name': 'Amit', 'Age': 23, 'Id Number': 456789, 'Phone Number': 123456}

# %% [markdown]
# * **Modifying Items in a Dictionary**
#
# To modify an existing item, you assign a new value to an existing key.

# %%
# let us consider a dictionary of phone number
phone_number={"Father": 123, "Mother": 456, "Brother": 789, "Sister": 159}
phone_number
# Out:
# {'Father': 123, 'Mother': 456, 'Brother': 789, 'Sister': 159}

# %%
# now we will change the phone number of brother
phone_number["Brother"]=357
phone_number
# this is the way of modifying data in a dictionary
# Out:
# {'Father': 123, 'Mother': 456, 'Brother': 357, 'Sister': 159}

# %% [markdown]
# * **Deleting Items from a Dictionary**
#
# You can remove an item from a dictionary using several methods:
#
# *  Using (del) function
#
# The del statement removes a key-value pair from the dictionary.

# %%
my_dict={"Name": "Amit", "Age": 23, "Id Number": 456789}
del my_dict["Age"]
my_dict
# Out:
# {'Name': 'Amit', 'Id Number': 456789}

# %% [markdown]
# *  Using .pop()
#
# The .pop() method removes an item by key and returns the value of the removed item.

# %%
phone_number={"Father": 123, "Mother": 456, "Brother": 789, "Sister": 159}
phone_number.pop("Sister")
# Out:
# 159

# %% [markdown]
# * Using .popitem()
#
# The .popitem() method removes and returns a random key-value pair as a tuple. It is useful when you don't know the key.

# %%
phone_number={"Father": 123, "Mother": 456, "Brother": 789, "Sister": 159}
phone_number.popitem()
# Out:
# ('Sister', 159)

# %% [markdown]
# * To get the value of a particular key
#
# we can get a particular value of a key by using get() function

# %%
new_dict={"Name": "Amit", "Age": 23, "Id Number": 456789}
new_dict.get("Name")
# Out:
# 'Amit'

# %% [markdown]
# * Using .clear()
#
# The .clear() method removes all items from the dictionary.

# %%
new_dict.clear()
print(new_dict)
# Out:
# {}

# %% [markdown]
# ##**Question-8) Discuss the importance of dictionary keys being immutable and provide examples.**
#
# **Answer-8)**  To understand why dictionary keys must be immutable. Let us related it to hash table. The hash table implementation of dictionaries uses a hash value calculated from the key value to find the key. If let’s say the key was a mutable object, its value could change, and thus its hash could also change.
#
# As stated above, since whoever changes the key object can’t tell that it was being used as a dictionary key, it can’t move the entry around in the dictionary. Then,
#
# * When you try to look up the same object in the dictionary it won’t be found because its hash value is different.
#
# * If you tried to look up the old value it wouldn’t be found either, because the value of the object found in that hash bin would be different.
#
# Examples of Immutable and Mutable Keys
# 1. Immutable Keys
# "Strings" are immutable, so they can be used as dictionary keys.

# %%
dict1={"Name": "Amit", "a": 23}
print(dict1)

# here in this dictionary both "name" and "a" are string
# values hence string can be used as a key
# Out:
# {'Name': 'Amit', 'a': 23}

# %% [markdown]
# 2. Integers are immutable and can also be used as dictionary keys.
#
# Integers can also be used as a key of dictionary as integers are also considered
# as immutable that means value of the key cannot be changed.

# %%
dict2={2: "abc", 3: "xyz"}
print(dict2)
# Out:
# {2: 'abc', 3: 'xyz'}

# %% [markdown]
# 3. Tuples are immutable and can be used as dictionary keys. This is particularly useful when you want to use composite data types.

# %%
dict3 = {(1, 2, 3): "Numbers"}
print(dict3)
# Out:
# {(1, 2, 3): 'Numbers'}

# %% [markdown]
# 4.  Mutable Keys
#
# Lists are mutable, meaning their content can change after creation, and therefore cannot be used as dictionary keys.

# %%
dict4={[1, 2, 3]: "Numbers"}
print(dict4)
# here we will get a error as lists cannot be a key
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-cbbde7216d36> in <cell line: 1>()
# ----> 1 dict4={[1, 2, 3]: "Numbers"}
#       2 print(dict4)
#       3 # here we will get a error as lists cannot be a key
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# 5. Dictionaries themselves are also mutable, so they cannot be used as dictionary keys.

# %%
dict5={{"Age": 23}: "abc"}
print(dict5)
# here also we will get a error as we cannot make dictionary as a key
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-599d4d4ad442> in <cell line: 1>()
# ----> 1 dict5={{"Age": 23}: "abc"}
#       2 print(dict5)
#       3 # here also we will get a error as we cannot make dictionary as a key
#
# TypeError: unhashable type: 'dict'
